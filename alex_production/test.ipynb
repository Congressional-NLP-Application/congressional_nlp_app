# %%
import fcs

# %%
api = fcs.con_create(r"C:\Users\Alex Lucchesi\OneDrive\Documents\GitHub\congressional_sentiment_NLP\app\.env")
print(api)
# Out:
# None

# %%
congress_member = 'PattyMurray'

public_tweets = api.user_timeline(screen_name=congress_member)
for tweet in public_tweets:
    print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tweepy\binder.py in execute(self)
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#
# ...
